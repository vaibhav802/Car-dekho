# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = 10, 5
plt.rcParams['figure.dpi'] = 100

# %%
df = pd.read_csv('Car details v3.csv')

# %%
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
seller = df['seller_type'].value_counts().index
owner = df['owner'].value_counts().index
C_name = list(df['name'].apply(lambda x: x.split()[0]).unique())
fuel = df['fuel'].value_counts().index

# %%
df['year'].value_counts().sort_index().plot(kind='bar')

# %%
sns.countplot(df['year'])
plt.xticks(rotation=90)
plt.show()
plt.savefig("Year_wise.jpg", bbox_inches="tight")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df['fuel'])
plt.xticks(rotation=90)
plt.title("Count of Fuel Type")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
avg_fuel_selling_price = df.groupby("fuel").selling_price.mean().reset_index()
plt.figure(facecolor="black")
ax = plt.gca()
ax.set_facecolor("black")
sns.barplot(avg_fuel_selling_price.fuel, avg_fuel_selling_price.selling_price)

plt.title("Average Selling Price base on Fuel Type")
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.pie(df['owner'].value_counts(),textprops=None,autopct=None)
# Out:
# ([<matplotlib.patches.Wedge at 0xc402d0a8b0>,
# ...
#  [Text(-0.5015854230227983, 0.9789852212424051, ''),
#   Text(0.2075056520872489, -1.0802506210837584, ''),
#   Text(1.032216260252954, -0.3801704776405, ''),
#   Text(1.0972193246271043, -0.07816491325934614, ''),
#   Text(1.0999979453680926, -0.002126072899797672, '')])

# %%
C_name
# Out:
# ['Maruti',
#  'Skoda',
#  'Honda',
#  'Hyundai',
#  'Toyota',
#  'Ford',
#  'Renault',
#  'Mahindra',
#  'Tata',
#  'Chevrolet',
#  'Fiat',
#  'Datsun',
#  'Jeep',
#  'Mercedes-Benz',
#  'Mitsubishi',
#  'Audi',
#  'Volkswagen',
#  'BMW',
#  'Nissan',
#  'Lexus',
#  'Jaguar',
#  'Land',
#  'MG',
#  'Volvo',
#  'Daewoo',
#  'Kia',
#  'Force',
#  'Ambassador',
#  'Ashok',
#  'Isuzu',
#  'Opel',
#  'Peugeot']

# %%
C_name = []
for i in df['name']:
    C_name.append(lambda x : x.split()[0])

# %%
C_name
# Out:
# [<function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
# ...

# %%
for i in data['Skills and Perks']:
        skills_perks.extend(list(map(lambda x: x[1:-1].strip().lower(), i[1:-1].split(","))))

# %%
seller = df['seller_type'].value_counts()

# %%
seller.index
# Out:
# Index(['Individual', 'Dealer', 'Trustmark Dealer'], dtype='object')

# %%
df['transmission'].value_counts()
# Out:
# Manual       7078
# Automatic    1050
# Name: transmission, dtype: int64

# %%
df['seller_type'].value_counts()
# Out:
# Individual          6766
# Dealer              1126
# Trustmark Dealer     236
# Name: seller_type, dtype: int64

# %%
df['name'].value_counts()
# Out:
# Maruti Swift Dzire VDI                129
# Maruti Alto 800 LXI                    82
# Maruti Alto LXi                        71
# BMW X4 M Sport X xDrive20d             62
# Maruti Swift VDI                       61
#                                      ...
# Maruti Esteem DI                        1
# Tata New Safari Dicor GX 4X2 BS IV      1
# Hyundai EON LPG Era Plus                1
# Tata Nexon 1.5 Revotorq XT              1
# BMW 5 Series 520d Sedan                 1
# Name: name, Length: 2058, dtype: int64

# %%
df['name'].apply(lambda x: x.split()[0]).value_counts()
# Out:
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Force               6
# Land                6
# Isuzu               5
# Kia                 4
# Ambassador          4
# MG                  3
# Daewoo              3
# Opel                1
# Ashok               1
# Peugeot             1
# Name: name, dtype: int64

# %%
text = []
for i in df.name:
    text.append(i.split()[0])
wordcloud = WordCloud().generate(str(set(text)))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("img1.jpg")

# %%
y = input()
df[df['name'].apply(lambda x : True if y in x else False)]
# Out:
# Volvo
#                                 name  year  selling_price  km_driven    fuel  \
# 145           Volvo XC40 D4 R-Design  2018        3400000      22000  Diesel
# 170    Volvo XC90 T8 Excellence BSIV  2017       10000000      30000  Petrol
# 374   Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 388            Volvo V40 D3 R-Design  2018        2475000       2000  Diesel
# 413   Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# ...                              ...   ...            ...        ...     ...
# 6977           Volvo V40 D3 R-Design  2018        2475000       2000  Diesel
# 7516  Volvo XC60 Inscription D5 BSIV  2018        5500000      50000  Diesel
# 7862  Volvo XC40 D4 Inscription BSIV  2019        3800000      20000  Diesel
# 7876           Volvo V40 D3 R-Design  2018        2475000       2000  Diesel
# 7930   Volvo S90 D4 Inscription BSIV  2019        5500000      17000  Diesel
#
# ...

# %%
data = pd.read_csv('cars_ds_final.csv')

# %%
pd.set_option('display.max_columns',None)

# %%
data.head(1)
# Out:
#    Unnamed: 0  Make      Model Variant Ex-Showroom_Price Displacement  \
# 0           0  Tata  Nano Genx      Xt      Rs. 2,92,667       624 cc
#
#    Cylinders  Valves_Per_Cylinder              Drivetrain  \
# 0        2.0                  2.0  RWD (Rear Wheel Drive)
#
#   Cylinder_Configuration Emission_Norm   Engine_Location Fuel_System  \
# 0                In-line         BS IV  Rear, Transverse   Injection
#
#   Fuel_Tank_Capacity Fuel_Type   Height   Length    Width  Body_Type  Doors  \
# 0          24 litres    Petrol  1652 mm  3164 mm  1750 mm  Hatchback    5.0
#
#      City_Mileage Highway_Mileage ARAI_Certified_Mileage  \
# 0  ?23.6 km/litre             NaN          23.6 km/litre
#
#   ARAI_Certified_Mileage_for_CNG Kerb_Weight Gears Ground_Clearance  \
# 0                            NaN      660 kg     4           180 mm
#
#   Front_Brakes Rear_Brakes                                   Front_Suspension  \
# ...

# %%
data.shape
# Out:
# (1276, 141)

# %%
data.drop('Unnamed: 0' , axis = 1,inplace = True)

# %%
data.head(1)
# Out:
#    Make      Model Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx      Xt      Rs. 2,92,667       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm   Engine_Location Fuel_System Fuel_Tank_Capacity Fuel_Type  \
# 0         BS IV  Rear, Transverse   Injection          24 litres    Petrol
#
#     Height   Length    Width  Body_Type  Doors    City_Mileage  \
# 0  1652 mm  3164 mm  1750 mm  Hatchback    5.0  ?23.6 km/litre
#
#   Highway_Mileage ARAI_Certified_Mileage ARAI_Certified_Mileage_for_CNG  \
# 0             NaN          23.6 km/litre                            NaN
#
#   Kerb_Weight Gears Ground_Clearance Front_Brakes Rear_Brakes  \
# 0      660 kg     4           180 mm         Drum        Drum
#
#                                     Front_Suspension  \
# 0  Independent, Lower Wishbone, McPherson Strut w...
#
# ...

# %%
data.dropna(how = 'all',axis =1,inplace = True)

# %%
data.head(5)
# Out:
#    Make      Model  Variant Ex-Showroom_Price Displacement  Cylinders  \
# 0  Tata  Nano Genx       Xt      Rs. 2,92,667       624 cc        2.0
# 1  Tata  Nano Genx       Xe      Rs. 2,36,447       624 cc        2.0
# 2  Tata  Nano Genx  Emax Xm      Rs. 2,96,661       624 cc        2.0
# 3  Tata  Nano Genx      Xta      Rs. 3,34,768       624 cc        2.0
# 4  Tata  Nano Genx       Xm      Rs. 2,72,223       624 cc        2.0
#
#    Valves_Per_Cylinder              Drivetrain Cylinder_Configuration  \
# 0                  2.0  RWD (Rear Wheel Drive)                In-line
# 1                  2.0  RWD (Rear Wheel Drive)                In-line
# 2                  2.0  RWD (Rear Wheel Drive)                In-line
# 3                  2.0  RWD (Rear Wheel Drive)                In-line
# 4                  2.0  RWD (Rear Wheel Drive)                In-line
#
#   Emission_Norm   Engine_Location Fuel_System Fuel_Tank_Capacity Fuel_Type  \
# ...

# %%
data['Displacement'].value_counts()
# Out:
# 1197 cc    108
# 1498 cc     87
# 1248 cc     62
# 1198 cc     58
# 1497 cc     56
#           ...
# 3855 cc      1
# 2982 cc      1
# 5198 cc      1
# 4497 cc      1
# 5950 cc      1
# Name: Displacement, Length: 129, dtype: int64

# %%
data.columns.get_loc('Power')
# Out:
# 38

# %%
data['Make'].value_counts()
# Out:
# Maruti Suzuki       149
# Hyundai             130
# Mahindra            119
# Tata                100
# Toyota               82
# Honda                64
# Ford                 43
# Skoda                43
# Bmw                  37
# Renault              36
# Volkswagen           34
# Audi                 31
# Nissan               29
# Jeep                 28
# Land Rover Rover     27
# Fiat                 23
# Jaguar               22
# Kia                  21
# Volvo                18
# Datsun               15
# Porsche              14
# Maruti Suzuki R      14
# Lamborghini          13
# Mg                   13
# Icml                 11
# Land Rover           10
# Mini                 10
# Lexus                10
# Maserati              9
# Ferrari               8
# Mitsubishi            7
# Force                 6
# Premier               6
# Bentley               6
# Isuzu                 5
# Aston Martin          3
# Bugatti               2
# Bajaj                 2
# ...

# %%
app.secret_key = b"_!@#$%^kafhdkfj@#$%^&lksdjf!@#$%^"


HOST = 'localhost'
PORT = 3306
USERNAME = 'root'
PASSWORD = ''
DATABASE = 'car'




try:
    DB = sql.connect(host=HOST, port=PORT, user=USERNAME, password=PASSWORD, database=DATABASE)
    CURSOR = DB.cursor()
    print("_____________Data Base Connected Sucessfully______________")
except:
    print("_____________Check DATABASE Connectivity First____________________")
    exit(0)

# %%
@app.route("/afterlogin", methods=['POST', 'GET'])
def login():
    if request.method == 'GET':
        abort(405)
    try:
        email = request.form['email']
        password = request.form['password']
        query = f"SELECT * FROM users WHERE email='{email}'"
        rows = CURSOR.execute(query)
        if rows == 0:
            flash("!! No Such Account Exists Please Signup !!")
            return redirect(url_for('form'))
        else:
            row = CURSOR.fetchone()
            upass = row[2]
            if upass == password:
                session['username'] = row[0]
                return render_template('afterlogin.html')
            else:
                flash("!! Error!! Invalid Password Try Again !!")
                return redirect(url_for('home'))
    except:
        flash( "!! Invalid Form Data !!")
        return redirect(url_for('home'))


@app.route('/aftersignup', methods=['POST'])
def do_signup():
    try:
        data = {
        'email': request.form['email'],
        'password': request.form['password'],
        'f_name' : request.form['First_name'],
        'l_name' : request.form['Last_name'],
        }
    except: 
        data = {'error': 'Invalid Form Data'}
    if 'error' not in data:
        query = f"SELECT * FROM users WHERE email='{data['email']}';"
        rows = CURSOR.execute(query)
        if rows != 0:
            flash("!!! User Account Already Exists Please Login to Continue !!!")
            return redirect(url_for('home'))
        
        else:
            query = f"INSERT INTO users (email, password, f_name, l_name) values\
('{data['email']}', '{data['password']}', '{data['f_name']}', '{data['l_name']}');"
            try:
                CURSOR.execute(query)
                DB.commit()
                flash("!!Account Sucessfully Created Please Login to Enjoy Services!!")
                return redirect(url_for('home'))
            except:
                flash("!! Error in Updating Database!!")
                return redirect(url_for('home'))
    else:
        flash(data['error'])
        return redirect(url_for('home'))

# %%
<style>
        body{
        background-image: url('../static/body-bg.jpg');
        background-repeat:no-repeat;
        background-position:center;
        background-size: cover;
        }
    </style>
